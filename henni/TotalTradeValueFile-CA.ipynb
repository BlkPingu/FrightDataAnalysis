# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df_ex = pd.read_csv('export_by_state_and_year_CA.csv', low_memory=False)
df_im = pd.read_csv('import_by_state_and_year_CA.csv', low_memory=False)

# %%
states = ['AL', 'AK', 'AS', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA','WA', 'WV', 'WI', 'WY']

# %%
df_total = df_ex.add(df_im, fill_value=0)

# %%
df_total.drop("2007", axis=1, inplace=True)
df_total.drop("2008", axis=1, inplace=True)
df_total.drop("2010", axis=1, inplace=True)
df_total.drop("2011", axis=1, inplace=True)
df_total.drop("2012", axis=1, inplace=True)
df_total["state"] = states
df_total
# Out:
#    state         2013         2014         2015         2016         2017  \
# 0     AL   6331458882   6465835531   6105157222   6187295126   6761875896
# 1     AK   1151652042   1159294028   1029541168    963670528   1161411155
# 2     AS            0            0            0            0            0
# 3     AZ   3788978076   3754250567   3720162263   3394373553   3510733109
# 4     AR   2579223755   2331528472   2003428169   1914783988   2046460376
# 5     CA  45262019389  46128588360  44782904179  43964080863  45494625407
# 6     CO   6097223143   5991982701   4610564037   4094144609   5030270574
# 7     CT   5683309359   5397765719   5069514186   4534969669   4768212339
# 8     DE   2205116602   2463787090   1360602565    980740437   1465789899
# 9     DC    146450666     62558365     65334867     77276494    103252097
# 10    FL   9656100523   8094712961   8074065606   7754769890   7981134480
# 11    GA  10441912505  11503814763  10609401873   9835029326  10416851755
# ...

# %%
df_total.to_csv("./trade_values_by_state_and_year_CA.csv", sep=',',index=False)
